# %%
import pandas as pd

# %%
data = pd.read_csv("Final (1).csv")

# %%
data.fillna(0, inplace = True)

# %%
data.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Team', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'years', 'Rank', 'First', 'Pts Won', 'Pts Max', 'Share', 'WS', 'WS/48',
#        'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'],
#       dtype='object')

# %%
data.sort_values("years", inplace = True)

# %%
data.shape
# Out:
# (12513, 45)

# %%
# data.set_index("years", inplace = True)

# %%
# data.sort_index(inplace = True)

# %%
data.years.unique()
# Out:
# array([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021], dtype=int64)

# %%
# data.fillna(0, inplace = True)

# %%
train = data[data.years<2021]

# %%
test = data[data.years==2021]

# %%
# from sklearn.model_selection import train_test_split

# %%
# train, test = train_test_split(data, test_size=0.1, shuffle = False)

# %%
train.years.unique()
# Out:
# array([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
test.years.unique()
# Out:
# array([2021], dtype=int64)

# %%
a= data.corr()["Share"]<0.7
pre = data.corr()['Share'][a].index.to_list()

# %%
b=data.corr()["Share"]
b
# Out:
# Rk        -0.016322
# Age        0.020841
# G          0.091323
# GS         0.170659
# MP         0.166651
# FG         0.284294
# FGA        0.257005
# FG%        0.065856
# 3P         0.099831
# 3PA        0.100512
# 3P%        0.032573
# 2P         0.283123
# 2PA        0.258732
# 2P%        0.062953
# eFG%       0.059172
# FT         0.324531
# FTA        0.329485
# FT%        0.042493
# ORB        0.103005
# DRB        0.219075
# TRB        0.190979
# AST        0.206627
# STL        0.179914
# BLK        0.158041
# TOV        0.240398
# PF         0.071779
# PTS        0.296349
# years     -0.006713
# First      0.831273
# Pts Won    0.995148
# Pts Max    0.520492
# Share      1.000000
# WS         0.651528
# WS/48      0.628255
# W          0.127471
# L         -0.126419
# W/L%       0.131403
# GB        -0.105445
# PS/G       0.045318
# PA/G      -0.038162
# SRS        0.127688
# Name: Share, dtype: float64

# %%
b[a].index
# Out:
# Index(['Rk', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'years', 'Pts Max', 'WS',
#        'WS/48', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'],
#       dtype='object')

# %%
# predictors = ['FT', 'FTA', 'First', 'WS', 'WS/48']

# %%
predictors = ['FG', 'FGA', '2P', '2PA', 'FT', 'FTA', 'DRB', 'AST', 'TOV', 'PTS', 'WS', 'WS/48']

# %%
# predict = ["Share"]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# ms = MinMaxScaler()
ms = StandardScaler()

# %%
x_test = test[pre] # x_test

# %%
x_test = ms.fit_transform(x_test)

# %%
x_train = train[pre]
x_train
# Out:
#           Rk  Age     G    GS         MP   FG   FGA    FG%   3P  3PA  ...  \
# 0      135.0   27  82.0  21.0  26.400000  3.1   6.6  0.476  0.1  0.7  ...
# 8150   259.0   25  74.0   3.0  13.100000  1.6   3.2  0.494  0.0  0.0  ...
# 8149   183.0   24  76.0   6.0  15.800000  2.1   4.4  0.467  0.0  0.0  ...
# 8148   267.0   25  82.0  82.0  36.799999  7.3  14.1  0.520  0.3  0.8  ...
# 8147   372.0   22  51.0   0.0   6.600000  1.0   2.0  0.510  0.0  0.0  ...
# ...      ...  ...   ...   ...        ...  ...   ...    ...  ...  ...  ...
# 1982   229.0   33  67.0  61.0  30.200001  4.8  10.6  0.450  1.5  4.2  ...
# 1991   400.0   26  24.0   0.0   9.700000  1.0   2.0  0.521  0.0  0.0  ...
# 1990   443.0   31  68.0  11.0  17.799999  2.2   5.1  0.426  1.2  3.2  ...
# 11308   56.0   27  62.0   0.0  13.200000  2.3   4.8  0.472  0.6  1.9  ...
# 1989   474.0   22  65.0  14.0  19.799999  1.7   4.1  0.423  0.9  2.4  ...
#
#        Pts Max   WS  WS/48     W     L   W/L%    GB   PS/G   PA/G   SRS
# ...

# %%
x_train = ms.fit_transform(x_train)

# %%
y_test = test["Share"]
y_test
# Out:
# 4932     0.000
# 4460     0.000
# 4462     0.000
# 4463     0.000
# 4464     0.000
#          ...
# 7071     0.000
# 7070     0.000
# 7069     0.000
# 2011     0.000
# 12512    0.001
# Name: Share, Length: 463, dtype: float64

# %%
y_train = train["Share"]
y_train
# Out:
# 0        0.0
# 8150     0.0
# 8149     0.0
# 8148     0.0
# 8147     0.0
#         ...
# 1982     0.0
# 1991     0.0
# 1990     0.0
# 11308    0.0
# 1989     0.0
# Name: Share, Length: 12050, dtype: float64

# %%
# x_test.fillna(0, inplace = True)

# %%
# x_train.fillna(0, inplace = True)

# %%
# y_train.fillna(0, inplace = True)

# %%
x_test.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-214-fab3a7e7e769> in <module>
# ----> 1 x_test.isna().sum()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isna'

# %%
# from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor

# %%
lr =RandomForestRegressor()
# lr = Ridge(alpha = 0.1)

# %%
lr.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
pr = lr.predict(x_test)

# %%
actual = y_test

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2_score(actual, pr)
# Out:
# 0.6277635976467959

# %%
predictions = pd.DataFrame(pr,  columns = ["Predictions"], index= test.index)
predictions
# Out:
#        Predictions
# 4932       0.00000
# 4460       0.00000
# 4462       0.00000
# 4463       0.00000
# 4464       0.00000
# ...            ...
# 7071       0.00000
# 7070       0.00000
# 7069       0.00000
# 2011       0.00000
# 12512      0.16143
#
# [463 rows x 1 columns]

# %%
combination = pd.concat([test[['Player', "Share"]] ,predictions], axis =1)
combination
# Out:
#                 Player  Share  Predictions
# 4932   Duncan Robinson  0.000      0.00000
# 4460        Cedi Osman  0.000      0.00000
# 4462    Damyean Dotson  0.000      0.00000
# 4463        Dante Exum  0.000      0.00000
# 4464    Darius Garland  0.000      0.00000
# ...                ...    ...          ...
# 7071      Shake Milton  0.000      0.00000
# 7070        Seth Curry  0.000      0.00000
# 7069     Rayjon Tucker  0.000      0.00000
# 2011      Théo Maledon  0.000      0.00000
# 12512     James Harden  0.001      0.16143
#
# [463 rows x 3 columns]

# %%
combination.sort_values("Share", ascending= False).head(10)
# Out:
#                       Player  Share  Predictions
# 9644            Nikola Jokić  0.961      0.79857
# 7065             Joel Embiid  0.580      0.50389
# 2883           Stephen Curry  0.449      0.35617
# 8130   Giannis Antetokounmpo  0.345      0.52788
# 1080              Chris Paul  0.138      0.12456
# 9268             Luka Dončić  0.042      0.16512
# 6100          Damian Lillard  0.038      0.28085
# 2777           Julius Randle  0.020      0.03650
# 12511           Derrick Rose  0.010      0.00262
# 9620             Rudy Gobert  0.008      0.18666

# %%
mean_squared_error(combination["Share"],combination["Predictions"])
# Out:
# 0.0005339990110151187

# %%
combination["Share"].value_counts().head()
# Out:
# 0.000    448
# 0.001      3
# 0.010      1
# 0.961      1
# 0.138      1
# Name: Share, dtype: int64

# %%
comb = combination.sort_values("Share", ascending =False)
comb
# Out:
#                      Player  Share  Predictions
# 9644           Nikola Jokić  0.961      0.79857
# 7065            Joel Embiid  0.580      0.50389
# 2883          Stephen Curry  0.449      0.35617
# 8130  Giannis Antetokounmpo  0.345      0.52788
# 1080             Chris Paul  0.138      0.12456
# ...                     ...    ...          ...
# 8902           Grant Riller  0.000      0.00000
# 8903        Jalen McDaniels  0.000      0.00000
# 8904            LaMelo Ball  0.000      0.00000
# 8905             Malik Monk  0.000      0.00000
# 9649             Zeke Nnaji  0.000      0.00000
#
# [463 rows x 3 columns]

# %%
comb["Rk"] = list(range(1,comb.shape[0]+1))

# %%
comb
# Out:
#                      Player  Share  Predictions   Rk
# 9644           Nikola Jokić  0.961      0.79857    1
# 7065            Joel Embiid  0.580      0.50389    2
# 2883          Stephen Curry  0.449      0.35617    3
# 8130  Giannis Antetokounmpo  0.345      0.52788    4
# 1080             Chris Paul  0.138      0.12456    5
# ...                     ...    ...          ...  ...
# 8902           Grant Riller  0.000      0.00000  459
# 8903        Jalen McDaniels  0.000      0.00000  460
# 8904            LaMelo Ball  0.000      0.00000  461
# 8905             Malik Monk  0.000      0.00000  462
# 9649             Zeke Nnaji  0.000      0.00000  463
#
# [463 rows x 4 columns]

# %%
comb = comb.sort_values("Predictions", ascending =False)
comb
# Out:
#                      Player  Share  Predictions   Rk
# 9644           Nikola Jokić  0.961      0.79857    1
# 8130  Giannis Antetokounmpo  0.345      0.52788    4
# 7065            Joel Embiid  0.580      0.50389    2
# 2883          Stephen Curry  0.449      0.35617    3
# 6100         Damian Lillard  0.038      0.28085    7
# ...                     ...    ...          ...  ...
# 848           Aaron Nesmith  0.000      0.00000  160
# 7075        Vincent Poirier  0.000      0.00000  159
# 7074           Tyrese Maxey  0.000      0.00000  158
# 7073          Tobias Harris  0.000      0.00000  157
# 9649             Zeke Nnaji  0.000      0.00000  463
#
# [463 rows x 4 columns]

# %%
comb["Predicted_Rk"] = list(range(1,comb.shape[0]+1))
comb.head(30)
# Out:
#                       Player  Share  Predictions   Rk  Predicted_Rk
# 9644            Nikola Jokić  0.961      0.79857    1             1
# 8130   Giannis Antetokounmpo  0.345      0.52788    4             2
# 7065             Joel Embiid  0.580      0.50389    2             3
# 2883           Stephen Curry  0.449      0.35617    3             4
# 6100          Damian Lillard  0.038      0.28085    7             5
# 9620             Rudy Gobert  0.008      0.18666   10             6
# 9268             Luka Dončić  0.042      0.16512    6             7
# 12512           James Harden  0.001      0.16143   13             8
# 4218           Kawhi Leonard  0.001      0.15921   14             9
# 1080              Chris Paul  0.138      0.12456    5            10
# 2956            LeBron James  0.001      0.12395   15            11
# 2777           Julius Randle  0.020      0.03650    8            12
# 7059             Ben Simmons  0.003      0.01971   12            13
# ...

# %%
comb['Rk'].unique()
# Out:
# array([  1,   4,   2,   3,   7,  10,   6,  13,  14,   5,  15,   8,  12,
#         11,  33, 390,   9, 315, 313, 314, 321, 316, 317, 318, 319, 320,
#        311, 312, 305, 310, 309, 308, 307, 306, 304, 323, 303, 302, 301,
#        300, 299, 298, 322, 331, 324, 338, 349, 348, 347, 346, 345, 344,
#        343, 342, 341, 340, 339, 337, 325, 336, 335, 334, 333, 332, 296,
#        330, 329, 328, 327, 326, 297, 288, 295, 254, 265, 264, 263, 262,
#        261, 260, 259, 258, 257, 256, 255, 253, 267, 252, 251, 250, 249,
#        248, 247, 246, 245, 244, 243, 242, 266, 268, 294, 282, 293, 292,
#        291, 290, 289, 351, 287, 286, 285, 284, 283, 281, 269, 280, 279,
#        278, 277, 276, 275, 274, 273, 272, 271, 270, 350, 359, 352, 423,
#        434, 433, 432, 431, 430, 429, 428, 427, 426, 425, 424, 422, 436,
#        421, 420, 419, 418, 417, 416, 415, 414, 413, 412, 411, 435, 437,
#        409, 451, 462, 461, 460, 459, 458, 457, 456, 455, 454, 453, 452,
# ...
